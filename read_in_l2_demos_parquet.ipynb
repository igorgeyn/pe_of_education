# %%
import pandas as pd
import numpy as np

# print('hello')

# %%
basic_demos_cols = ['Voters_LastName', 'Voters_FirstName', 'Voters_BirthDate',
                    'Voters_Active', ## probably won't use this
                    # Voters_StateVoterID, Voters_CountyVoterID ## to avoid ID'ing
                    'Residence_Addresses_City', 'Residence_Addresses_State', 'Residence_Addresses_Zip',
                    'Residence_Addresses_Latitude', 'Residence_Addresses_Longitude',
                    'Residence_Addresses_ApartmentType',
                    'Residence_Families_HHCount',
                    'Voters_Gender', 'Voters_Age',
                    'Parties_Description', 'VoterParties_Change_Changed_Party',
                    'Ethnic_Description', 'EthnicGroups_EthnicGroup1Desc',
                    'Languages_Description', 'MilitaryStatus_Description', 'MaritalStatus_Description']
basic_demos_cols

# %%
## read in a few rows of the demos df.

demos_for_colnames = pd.read_csv('C:/Users/Igor/Downloads/VM2--CA--2022-07-01-DEMOGRAPHIC.tab', 
                    sep='\t', 
                    nrows=1000, 
                    # usecols = ['Voters_LastName', 'Voters_FirstName']
                    # usecols = basic_demos_cols
                    )
demos_for_colnames.head()

# data_subset = data[basic_demos_cols]

# data_subset = data[basic_demos_cols]
# data_subset.head()

# %%
# demos_for_colnames.to_parquet(path = 'I:/data/college_politics/l2_demos_for_cols_parquet.parquet.gzip', compression='gzip')
# demos_for_colnames.to_parquet(path = 'I:/data/college_politics/l2_demos_for_cols_parquet.parquet')

parquet_test = pd.read_parquet('I:/data/college_politics/l2_demos_for_cols_parquet.parquet', engine='pyarrow')
parquet_test.head()

# %%
### try out pulling column names from data subset

elec_margins_general_county = [col for col in demos_for_colnames if col.startswith('ElectionReturns_G08_Cnty_Margin_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G10_Cnty_Margin_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G12_Cnty_Margin_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G14_Cnty_Margin_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G16_Cnty_Margin_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G18_Cnty_Margin_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G20_Cnty_Margin_')]

# elec_margins_general_county

elec_vote_count_general_county = [col for col in demos_for_colnames if col.startswith('ElectionReturns_G08_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G10_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G12_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G14_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G16_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G18_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G20_Cnty_Vote_')]

elec_vote_pct_general_county = [col for col in demos_for_colnames if col.startswith('ElectionReturns_G08_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G10_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G12_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G14_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G16_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G18_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_G20_Cnty_Pct_')]

elec_vote_pct_primary_county = [col for col in demos_for_colnames if col.startswith('ElectionReturns_P08_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P10_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P12_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P14_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P16_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P18_Cnty_Pct_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P20_Cnty_Pct_')]

elec_vote_count_primary_county = [col for col in demos_for_colnames if col.startswith('ElectionReturns_P08_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P10_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P12_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P14_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P16_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P18_Cnty_Vote_')] + \
                                [col for col in demos_for_colnames if col.startswith('ElectionReturns_P20_Cnty_Vote_')]

# elec_vote_pct_primary_county
# elec_vote_count_primary_county

# %%
l2_demos_data_margins_and_votes = pd.read_csv('C:/Users/Igor/Downloads/VM2--CA--2022-07-01-DEMOGRAPHIC.tab', 
                    sep='\t', 
                    # nrows=1000000, 
                    # usecols = ['Voters_LastName', 'Voters_FirstName']
                    usecols = 
                    ['LALVOTERID'] + elec_margins_general_county + elec_vote_count_general_county + \
                        elec_vote_count_primary_county + elec_vote_pct_general_county + elec_vote_pct_primary_county
                    )
# demos_for_colnames.head()
columns_test = list(l2_demos_data_margins_and_votes.columns.values)
# columns_test

# %%
print(l2_demos_data_margins_and_votes.shape[0])
l2_demos_data_margins_and_votes.head()

# %%
l2_demos_data_margins_and_votes.to_parquet(path = 'I:/data/college_politics.l2_demos_margins_parquet.parquet.gzip', compression='gzip') ## create a gzipped parquet file
l2_demos_data_margins_and_votes.to_parquet(path = 'I:/data/college_politics.l2_demos_margins_parquet.parquet') ## parquet file with no gzip

# %%
from pathlib import Path
filepath = Path('I:/data/college_politics/l2_demos_margins.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  

l2_demos_data_margins_and_votes.to_csv(filepath)

# %%
import os ## JIC

# l2_demos_data_margins_and_votes_parquet = 
# l2_demos_data_margins_and_votes.to_parquet(path = 'I:/data/college_politics.l2_demos_margins_parquet.parquet.gzip', compression='gzip')

os.makedirs('I:/data/college_politics', exist_ok=True)  
l2_demos_data_margins_and_votes.to_csv('I:/data/college_politics/l2_demos_margins.csv')

# %% [markdown]
# ### Putting data together for CSAC.
#
# Now that everything has been written in, it's time to put it all together for CSAC. Be sure to detail exactly how this is being done (for blog, but also for posterity).

# %% [markdown]
# #### File roadmap:
#
# Start with `participation_variables`. Then, left-join on each of the following:
#
# - `ballot_type_variables`
# - `voting_logistics_vars`
# - `basic_demo_vars`
# - `voter_chars_dists_other_vars`
# - `turnout_vars`
# - `elec_margins_vars`

# %%
### First way is to just read in .CSVs (converting to pandas dataframes), join/merge/append everything, and
### then output as a .CSV.
### Lingering question: How to share with Ryan?

# Read in and quickly examine `participation_variables`:

participation_variables = pd.read_csv('I:/data/college_politics/participation_variables.csv',
                                # nrows = 1000, 
                                header=0,
                                low_memory=False)
participation_variables.head()

# SOME CODE HERE
# Out:
#    Unnamed: 0 General_2020_11_03 General_2018_11_06 General_2016_11_08  \
# 0           1                NaN                NaN                  Y
# 1           2                  Y                  Y                  Y
# 2           3                  Y                NaN                NaN
# 3           4                  Y                  Y                  Y
# 4           5                NaN                NaN                NaN
#
#   General_2014_11_04 General_2012_11_06 General_2010_11_02 General_2008_11_04  \
# 0                NaN                  Y                NaN                  Y
# 1                  Y                  Y                  Y                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                  Y                NaN                  Y
# 4                NaN                NaN                NaN                NaN
#
#   General_2006_11_07 General_2004_11_02  ... Runoff_2006_01_10  \
# ...

# %%
ballot_type_variables = pd.read_csv('I:/data/college_politics/ballot_type_variables.csv',
                                # nrows = 1000000, 
                                header=0,
                                # dtype={},
                                low_memory=False)
# ballot_type_variables.head()

# %%
voting_logistics_vars = pd.read_csv('I:/data/college_politics/voting_logistics_vars.csv',
                                # nrows = 1000000, 
                                header=0,
                                # dtype={},
                                low_memory=False)
# voting_logistics_vars.head()



basic_demo_vars = pd.read_csv('I:/data/college_politics/basic_demo_vars.csv',
                                # nrows = 1000000, 
                                header=0,
                                # dtype={},
                                low_memory=False)
# basic_demo_vars.head()



voter_chars_dists_other_vars = pd.read_csv('I:/data/college_politics/voter_chars_dists_other_vars.csv',
                                # nrows = 1000000, 
                                header=0,
                                # dtype={},
                                low_memory=False)
# voter_chars_dists_other_vars.head()

# %%
turnout_vars = pd.read_csv('I:/data/college_politics/turnout_vars.csv',
                                # nrows = 1000000, 
                                header=0,
                                # dtype={},
                                low_memory=False)
# turnout_vars.head()


elec_margins_vars = pd.read_csv('I:/data/college_politics/elec_margins_vars.csv',
                                # nrows = 1000000, 
                                header=0,
                                # dtype={},
                                low_memory=False)
# elec_margins_vars.head()

# %%
### The next way is to instead read in the .CSV to pandas dataframes, but then to convert to Parquet
### (both for storage and for use in Python), and then eventually upload a Parquet file.
### Lingering question: How will Ryan access the Parquet file?
### Another question: Is there an advantage to covnerting to Parquet prior to all the joining? 



# SOME CODE HERE

# %% [markdown]
# ### Additional scraps.
#
# These are misc. bits from analysis done in other places. This is from the R code used to do a similar thing.

# %%
### define columns

# maybe don't need this? tho it is convenient.
elec_margins_general_county = 
  # colnames(
    c(
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G08_Cnty_Margin_"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G10_Cnty_Margin_"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G12_Cnty_Margin_"))) %>% colnames(), 
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G14_Cnty_Margin_"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G16_Cnty_Margin_"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G18_Cnty_Margin_"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G20_Cnty_Margin_"))) %>% colnames()
    )
  # )

elec_vote_count_general_county = 
  # colnames(
    c(
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G08_Cnty_Vote"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G10_Cnty_Vote"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G12_Cnty_Vote"))) %>% colnames(), 
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G14_Cnty_Vote"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G16_Cnty_Vote"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G18_Cnty_Vote"))) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(c(starts_with("ElectionReturns_G20_Cnty_Vote"))) %>% colnames()
    )
  # )

elec_vote_pct_general_county = 
  # colnames(
    c(
      l2_2022_07_demos_for_colnames %>% select(starts_with("ElectionReturns_G08_Cnty_Pct")) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(starts_with("ElectionReturns_G10_Cnty_Pct")) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(starts_with("ElectionReturns_G12_Cnty_Pct")) %>% colnames(), 
      l2_2022_07_demos_for_colnames %>% select(starts_with("ElectionReturns_G14_Cnty_Pct")) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(starts_with("ElectionReturns_G16_Cnty_Pct")) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(starts_with("ElectionReturns_G18_Cnty_Pct")) %>% colnames(),
      l2_2022_07_demos_for_colnames %>% select(starts_with("ElectionReturns_G20_Cnty_Pct")) %>% colnames()
    )
  # )

### read in margins and election vote / percent

# elec_margins_general_county, ## two-party victory margin by election (general)
# elec_vote_count_general_county, ## number of votes for candidates in election (general)
# elec_vote_count_primary_county, ## number of votes for candidates in election (primary)
# elec_vote_pct_general_county, ## voteshare for candidates in election (general)
# elec_vote_pct_primary_county, ## voteshare for candidates in election (primary)
